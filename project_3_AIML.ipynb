# %% [markdown]
# # **HOUSE PRICE PREDICTION MODEL BY LINEAR REGRESSION**

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import model_selection

# %%
data = pd.read_csv("/content/drive/MyDrive/datasets/house_price_dataset.csv")
data.head()
# Out:
#       h_type location       society   size  bathroom  balcony  total_sqft  \
# 0  apartment   Maneja  Bakeri Swara  3 BHK         3        1      1550.0
# 1  apartment   Maneja  Bakeri Swara  3 BHK         3        1      1550.0
# 2  apartment   Maneja  Bakeri Swara  3 BHK         3        1      1860.0
# 3  apartment   Maneja  Bakeri Swara  2 BHK         2        1      1015.0
# 4  apartment   Maneja  Bakeri Swara  2 BHK         2        1      1210.0
#
#    yr_built  furniture sale_type  ...  college  hospital  population  railway  \
# 0    2011.0          0       new  ...        0         1           2        0
# 1    2012.0          1       new  ...        0         1           2        0
# 2    2010.0          1       new  ...        0         1           2        0
# 3    2016.0          1       new  ...        0         1           2        0
# 4    2019.0          0       new  ...        0         1           2        0
#
#    airport  on_road  air_quality  restaurant  park    price
# 0        0        1            1           1     1  4361705
# 1        0        1            1           1     1  5001905
# 2        0        1            1           1     1  5588795
# 3        0        1            1           1     1  3184740
# 4        0        1            1           1     1  3498895
#
# [5 rows x 24 columns]

# %%
data = data.drop(['society', 'yr_built', 'furniture', 'sale_type', 'amenities', 'market', 'office', 'school', 'college', 'hospital', 'population', 'railway', 'airport', 'on_road', 'air_quality', 'restaurant', 'park'], axis=1)
data.head()
# Out:
#       h_type location   size  bathroom  balcony  total_sqft    price
# 0  apartment   Maneja  3 BHK         3        1      1550.0  4361705
# 1  apartment   Maneja  3 BHK         3        1      1550.0  5001905
# 2  apartment   Maneja  3 BHK         3        1      1860.0  5588795
# 3  apartment   Maneja  2 BHK         2        1      1015.0  3184740
# 4  apartment   Maneja  2 BHK         2        1      1210.0  3498895

# %%
data.isnull().sum()
# Out:
# h_type        0
# location      0
# size          0
# bathroom      0
# balcony       0
# total_sqft    0
# price         0
# dtype: int64

# %%
df = data.iloc[ : , :-1].values
df
# Out:
# array([['apartment', 'Maneja', '3 BHK', 3, 1, 1550.0],
#        ['apartment', 'Maneja', '3 BHK', 3, 1, 1550.0],
#        ['apartment', 'Maneja', '3 BHK', 3, 1, 1860.0],
#        ...,
#        ['apartment', 'Gotri', '3 BHK', 3, 3, 1550.0],
#        ['apartment', 'Gotri', '3 BHK', 3, 2, 1750.0],
#        ['apartment', 'Gotri', '2 BHK', 2, 3, 1200.0]], dtype=object)

# %%
label_encoder = LabelEncoder()

# %%
df[ : ,0] = label_encoder.fit_transform(df[ : ,0])
df
# Out:
# array([[0, 'Maneja', '3 BHK', 3, 1, 1550.0],
#        [0, 'Maneja', '3 BHK', 3, 1, 1550.0],
#        [0, 'Maneja', '3 BHK', 3, 1, 1860.0],
#        ...,
#        [0, 'Gotri', '3 BHK', 3, 3, 1550.0],
#        [0, 'Gotri', '3 BHK', 3, 2, 1750.0],
#        [0, 'Gotri', '2 BHK', 2, 3, 1200.0]], dtype=object)

# %%
mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
mapping
# Out:
# {'apartment': np.int64(0),
#  'duplex': np.int64(1),
#  'pent house': np.int64(2),
#  'tenament': np.int64(3),
#  'triplex': np.int64(4),
#  'villa': np.int64(5)}

# %%
df[ : ,1] = label_encoder.fit_transform(df[ : ,1])
df
# Out:
# array([[0, 15, '3 BHK', 3, 1, 1550.0],
#        [0, 15, '3 BHK', 3, 1, 1550.0],
#        [0, 15, '3 BHK', 3, 1, 1860.0],
#        ...,
#        [0, 8, '3 BHK', 3, 3, 1550.0],
#        [0, 8, '3 BHK', 3, 2, 1750.0],
#        [0, 8, '2 BHK', 2, 3, 1200.0]], dtype=object)

# %%
mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
mapping
# Out:
# {'Ajwa Road': np.int64(0),
#  'Akota': np.int64(1),
#  'Alkapuri': np.int64(2),
#  'Atladra': np.int64(3),
#  'Bhayli': np.int64(4),
#  'Chhani': np.int64(5),
#  'Fatehgunj': np.int64(6),
#  'Gorwa': np.int64(7),
#  'Gotri': np.int64(8),
#  'Harni': np.int64(9),
#  'Karelibaug': np.int64(10),
#  'Khodiyar Nagar': np.int64(11),
#  'Laxmipura': np.int64(12),
#  'Madhav Pura': np.int64(13),
#  'Mandvi': np.int64(14),
#  'Maneja': np.int64(15),
#  'Manjalpur': np.int64(16),
#  'Navapura': np.int64(17),
#  'New Alkapuri': np.int64(18),
#  'New Karelibaugh': np.int64(19),
#  'New Sama': np.int64(20),
#  'New VIP Road': np.int64(21),
#  'Sama': np.int64(22),
#  'Sayajipura': np.int64(23),
#  'Soma Talav': np.int64(24),
#  'Vasant Vihar': np.int64(25),
#  'Vasna Road': np.int64(26),
#  'Vasna-Bhayli Road': np.int64(27),
#  'Waghodia Road': np.int64(28)}

# %%
df[ : ,2] = label_encoder.fit_transform(df[ : ,2])
df
# Out:
# array([[0, 15, 2, 3, 1, 1550.0],
#        [0, 15, 2, 3, 1, 1550.0],
#        [0, 15, 2, 3, 1, 1860.0],
#        ...,
#        [0, 8, 2, 3, 3, 1550.0],
#        [0, 8, 2, 3, 2, 1750.0],
#        [0, 8, 1, 2, 3, 1200.0]], dtype=object)

# %%
mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
mapping
# Out:
# {'1 BHK': np.int64(0),
#  '2 BHK': np.int64(1),
#  '3 BHK': np.int64(2),
#  '4 BHK': np.int64(3),
#  '5 BHK': np.int64(4)}

# %%
y = data.price.values
X = df

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.2)

standard_x = StandardScaler()

# %%
X_train = standard_x.fit_transform(X_train)
X_val = standard_x.transform(X_val)

# %%
print('Train_Shape: ',X_train.shape)
print("\nX_train:")
X_train
# Out:
# Train_Shape:  (272, 6)
#
# X_train:
# array([[-0.38829014,  1.47114255,  0.37553511,  0.4108774 , -0.62570424,
#          0.76559597],
#        [ 0.5547002 ,  0.62358995,  0.37553511,  0.4108774 ,  0.46526725,
#          0.0370897 ],
#        [ 0.5547002 ,  1.57708663,  1.56327406,  0.4108774 , -0.62570424,
#          0.50798729],
#        ...,
#        [-0.38829014, -0.75368304, -0.81220384, -0.64344952, -0.62570424,
#         -0.93240533],
#        [-0.38829014,  1.04736625, -1.9999428 , -1.69777645, -0.62570424,
#         -1.14015426],
#        [ 0.5547002 ,  1.57708663, -0.81220384, -0.64344952,  0.46526725,
#         -0.30777353]])

# %%
print('Val_Shape: ',X_val.shape)
print("\nX_val:")
X_val
# Out:
# Val_Shape:  (68, 6)
#
# X_val:
# array([[-0.38829014, -0.75368304,  0.37553511,  0.4108774 ,  0.46526725,
#          1.4220826 ],
#        [-0.38829014, -0.32990674, -0.81220384, -0.64344952, -0.62570424,
#         -0.37840817],
#        [-0.38829014, -1.07151527,  1.56327406,  1.46520433,  1.55623874,
#          0.86808544],
#        [-0.38829014, -0.32990674,  0.37553511,  0.4108774 ,  0.46526725,
#          0.38056794],
#        [-0.38829014,  1.47114255, -0.81220384, -0.64344952, -1.71667573,
#         -0.44765781],
#        [ 0.5547002 ,  1.57708663,  0.37553511,  0.4108774 , -0.62570424,
#         -0.44765781],
#        [-0.38829014,  0.62358995,  0.37553511,  0.4108774 , -0.62570424,
#         -0.17065923],
#        [-0.38829014, -0.43585081,  0.37553511,  0.4108774 , -0.62570424,
#          1.54811696],
#        [-0.38829014, -1.28340342,  0.37553511,  0.4108774 ,  0.46526725,
#          0.72958615],
#        [ 0.5547002 ,  1.57708663,  0.37553511,  0.4108774 ,  0.46526725,
#          0.12988423],
#        [-0.38829014, -0.22396266,  0.37553511,  0.4108774 ,  0.46526725,
#         -0.12218448],
#        [-0.38829014,  1.47114255,  1.56327406,  1.46520433,  1.55623874,
#          1.14508402],
#        [-0.38829014, -0.11801858, -1.9999428 , -1.69777645, -0.62570424,
#         -1.57642703],
#        [ 4.32666153, -0.96557119,  1.56327406,  1.46520433,  0.46526725,
#          0.29331339],
#        [ 0.5547002 ,  1.04736625, -0.81220384, -0.64344952, -0.62570424,
#         -1.33128328],
#        [-0.38829014, -1.28340342,  0.37553511,  0.4108774 , -0.62570424,
#          0.21021382],
#        [-0.38829014,  0.30575772,  0.37553511,  0.4108774 ,  1.55623874,
#          0.09248942],
#        [-0.38829014, -0.43585081,  0.37553511,  0.4108774 , -0.62570424,
#          0.28223345],
#        [-0.38829014, -1.07151527,  0.37553511,  0.4108774 ,  0.46526725,
#          0.45258757],
#        [ 4.32666153, -0.32990674,  1.56327406,  1.46520433,  0.46526725,
#         -0.43380788],
#        [-0.38829014, -0.96557119,  0.37553511,  0.4108774 , -1.71667573,
#          0.21021382],
#        [ 0.5547002 ,  1.57708663,  1.56327406,  1.46520433, -0.62570424,
#         -0.26622374],
#        [ 4.32666153,  0.30575772,  0.37553511,  0.4108774 , -0.62570424,
#         -0.65540675],
#        [-0.38829014,  1.36519848,  0.37553511,  0.4108774 ,  0.46526725,
#          0.07171453],
#        [ 4.32666153,  0.30575772,  1.56327406,  0.4108774 , -0.62570424,
#          0.72958615],
#        [-0.38829014,  0.72953402, -1.9999428 , -1.69777645, -0.62570424,
#         -1.29250348],
#        [ 4.32666153,  0.30575772,  1.56327406,  0.4108774 , -0.62570424,
#         -0.93240533],
#        [ 0.5547002 , -1.38934749,  1.56327406,  1.46520433, -0.62570424,
#         -0.17065923],
#        [-0.38829014, -0.32990674, -0.81220384, -0.64344952, -0.62570424,
#         -0.30915852],
#        [-0.38829014, -0.75368304,  0.37553511, -0.64344952, -0.62570424,
#         -0.57230717],
#        [-0.38829014,  0.41170179, -0.81220384, -1.69777645, -1.71667573,
#         -0.51690746],
#        [-0.38829014, -0.32990674,  1.56327406,  2.51953125,  3.73818172,
#          2.78214563],
#        [-0.38829014, -0.43585081,  0.37553511,  0.4108774 ,  0.46526725,
#         -0.61108698],
#        [-0.38829014, -0.43585081,  0.37553511,  0.4108774 , -0.62570424,
#         -0.79350439],
#        [-0.38829014,  1.57708663,  0.37553511,  0.4108774 ,  1.55623874,
#          0.72958615],
#        [-0.38829014, -0.22396266, -0.81220384, -0.64344952,  0.46526725,
#         -0.30915852],
#        [-0.38829014,  1.57708663, -0.81220384, -0.64344952, -1.71667573,
#         -0.87700561],
#        [-0.38829014, -0.85962712, -0.81220384, -0.64344952, -1.71667573,
#         -0.03908491],
#        [-0.38829014,  0.19981364,  1.56327406,  1.46520433, -0.62570424,
#          1.56750686],
#        [-0.38829014,  1.36519848,  0.37553511,  0.4108774 , -0.62570424,
#          0.72958615],
#        [-0.38829014, -0.85962712, -0.81220384, -0.64344952,  0.46526725,
#         -0.86315568],
#        [-0.38829014, -0.54179489,  0.37553511,  0.4108774 ,  0.46526725,
#          0.38333793],
#        [ 4.32666153,  0.30575772,  0.37553511,  0.4108774 ,  0.46526725,
#         -0.17065923],
#        [ 1.49769053, -0.32990674,  1.56327406,  1.46520433,  0.46526725,
#          5.21834815],
#        [-0.38829014, -0.75368304, -0.81220384, -0.64344952, -0.62570424,
#         -0.42688292],
#        [-0.38829014, -0.54179489, -0.81220384, -0.64344952,  1.55623874,
#         -0.37840817],
#        [-0.38829014, -1.17745934, -0.81220384, -1.69777645, -0.62570424,
#         -0.86315568],
#        [ 0.5547002 , -1.38934749,  0.37553511, -0.64344952, -0.62570424,
#          0.758671  ],
#        [-0.38829014, -0.85962712, -0.81220384, -0.64344952, -1.71667573,
#         -0.5861571 ],
#        [-0.38829014, -0.85962712,  0.37553511,  0.4108774 , -0.62570424,
#          0.81268573],
#        [-0.38829014, -0.11801858, -0.81220384, -0.64344952, -0.62570424,
#         -0.44765781],
#        [ 0.5547002 ,  0.62358995, -1.9999428 , -1.69777645, -0.62570424,
#         -0.94348527],
#        [-0.38829014,  0.51764587,  0.37553511,  0.4108774 ,  0.46526725,
#         -0.77313114],
#        [-0.38829014, -0.01207451, -0.81220384, -0.64344952,  1.55623874,
#         -0.26760874],
#        [ 0.5547002 ,  0.62358995,  0.37553511,  0.4108774 ,  0.46526725,
#         -0.17065923],
#        [-0.38829014,  1.57708663,  0.37553511,  0.4108774 ,  1.55623874,
#         -0.10140959],
#        [ 3.3836712 ,  0.30575772,  1.56327406,  0.4108774 ,  0.46526725,
#          1.00658473],
#        [-0.38829014, -0.85962712, -0.81220384, -0.64344952, -0.62570424,
#         -0.85761571],
#        [-0.38829014, -0.43585081,  0.37553511,  0.4108774 ,  0.46526725,
#          0.45951254],
#        [-0.38829014, -1.38934749, -0.81220384, -0.64344952, -0.62570424,
#         -0.08063469],
#        [-0.38829014, -0.32990674, -0.81220384, -0.64344952,  0.46526725,
#          0.07171453],
#        [-0.38829014, -0.75368304, -0.81220384, -0.64344952, -0.62570424,
#         -0.65540675],
#        [-0.38829014,  0.8354781 , -0.81220384, -0.64344952, -0.62570424,
#         -0.26760874],
#        [ 0.5547002 ,  1.57708663,  0.37553511,  0.4108774 , -0.62570424,
#         -0.62078193],
#        [ 4.32666153, -0.11801858,  1.56327406,  0.4108774 ,  0.46526725,
#          0.17558899],
#        [-0.38829014,  0.62358995,  1.56327406,  1.46520433,  1.55623874,
#          0.17558899],
#        [ 0.5547002 ,  0.8354781 ,  0.37553511,  0.4108774 ,  0.46526725,
#          0.09941438],
#        [-0.38829014, -0.96557119, -0.81220384, -0.64344952, -0.62570424,
#         -0.72465639]])

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_val)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


print("R² Score:", r2_score(y_val, y_pred))
print("MAE:", mean_absolute_error(y_val, y_pred))
print("MSE:", mean_squared_error(y_val, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_val, y_pred)))
# Out:
# R² Score: 0.6844597792410183
# MAE: 1805434.8377981104
# MSE: 5344062507310.734
# RMSE: 2311722.8439652394
